# %% [markdown]
# <a href="https://colab.research.google.com/github/Demosthene-OR/Student-AI-and-Data-Management/blob/main/06_Dense_Neural_Network_Tabular_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://prof.totalenergies.com/wp-content/uploads/2024/09/TotalEnergies_TPA_picto_DegradeRouge_RVB-1024x1024.png" height="150" width="150">
#
#
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Introduction to Deep Learning with Keras</h1></center>
# <center><h2>Predictions using Dense Neural Networks on tabular data</h2></center>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# ## Context and Objective
#
# >As mentioned previously, the simple perceptron algorithm is not really useful. It is better to consider a multilayer perceptron to observe interesting results. The following GIF illustrates this:
# >
# ><img src="https://assets-datascientest.s3-eu-west-1.amazonaws.com/notebooks/masterclass_deeplearning_debutant_intro_dense.gif" style="width:400px">
# >
# >**We will now look at an example of a multilayer perceptron model on the well-known IRIS dataset.** As a reminder, this dataset is the most widely used for species recognition projects. It contains visual information on three species of iris, each described by 50 observations. The objective is therefore to recognize the iris flower based on certain characteristic measurements grouped together in **tabular** data.
#
# * **(a)** Run the following cell to import the necessary packages:

# %%
import numpy as np # Pour la manipulation de tableaux

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from tensorflow.keras.layers import Input, Dense #Pour instancier une couche Dense et une d'Input
from tensorflow.keras.models import Model

# %% [markdown]
# ## Data loading and preprocessing
#
# * **(b)** Read the **Iris.csv** file into a dataframe df, specify the **Id** column to contain the indexes, and display the first 5 rows.

# %%
## Insérez votre code ici

# %%
url = "https://raw.githubusercontent.com/Demosthene-OR/Student-AI-and-Data-Management/main/data/"
df=pd.read_csv(url+'Iris.csv', index_col = 'Id')
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# * **(c)** Separate the explanatory variables from the target variable.
# * **(d)** Encode the target variable, **`‘Species’`**, according to each species.

# %%
## Insert your code here

# %%
#Splitting the data into training and test test
X = df.iloc[:,0:4].values
y = df.iloc[:,4].values

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
Y = encoder.fit_transform(y)

# %% [markdown]
# * **(e)** Separate the data into a training set and a test set. The test set will account for **one-third** of the dataset.

# %%
## Insert your code here

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.33,random_state=42)

# %% [markdown]
# ## Multi-Layer Perceptron
#
# > The multi-layer perceptron model is a **sequence of perceptron layers** whose input is the output of the **previous layer**.
# >
# > Consider a 3-layer perceptron model. For a given input vector $x$, the output of the first layer is:
# >
# > $$ H_1 = \mathrm{Layer_1}(x) $$
# >
# > Next, the vector $H_1$ is fed into the second layer:
# >
# > $$ H_2 = \mathrm{Layer_2}(H_1) $$
# >
# > Finally, the vector $H_2$ is fed into the third layer to obtain the final output of the model:
# >
# > $$ O = \mathrm{Layer_3}(H_2) $$
# >
# > <img src = "https://assets-datascientest.s3-eu-west-1.amazonaws.com/notebooks/perceptron3.png">
# >
# > Multilayer perceptrons can be constructed **sequentially** by stacking dense layers one after the other. You will sometimes encounter this notation in Keras, although in this module we have decided to use the **functional** construction, which is more versatile and is used more often when writing complex models that may have a non-linear structure or take different inputs.
#
# ## Building and Training a Model
#
#
#
#
# > We will build our model by adding layers one by one, from the input layer to the output layer.
# >
# > Building a model with **Keras** is very easy with the following steps:
# >
# >
# >* **Step 1**: Import the `Input` and `Dense` classes from the `tensorflow.keras.layers` submodule and the `Model` class from the `tensorflow.keras.models` submodule
# >
# > ```python
# > from tensorflow.keras... import ...
# >```
# >
# > * **Step 2**: Instantiate an input layer that contains the dimensions of our input data.
# >
# > ```python
# > inputs = Input(shape = (..), name = “Input”)
# >```
# >
# > * **Step 3**: Instantiate the layers that will make up the model with their constructor. To instantiate a dense layer, use the `Dense` constructor, which we have imported.
# >
# >```python
# > dense1 = Dense(units = ..., activation = “...”, name = “Layer_1”)
# >```
# >
# > * **Step 4**: Apply the layers one by one (**functional** construction).
# >
# >```python
# > x = dense1(inputs)
# > x = dense2(x)
# > ...
# >```
# >
# > Instantiating layers involves several nuances:
# >
# > * The first layer we are going to add to the model must be instantiated **by specifying the dimensions of the input vector** with the **shape** parameter. This specification is not necessary for subsequent layers.
# >
# >
# > * The **number of neurons** in a layer is defined with the **units** parameter.
# >
# >
# > * To add an activation function to a neuron layer, you can either instantiate an activation layer and then add it to the model, or define the activation function in the **activation** parameter of the layer constructor.
# >
#
# * **(a)** Instantiate an inputs layer, with the number of explanatory variables in the model as its dimension.
#
#
# * **(b)** Instantiate a dense layer called **`dense1`** with 10 neurons. This layer will have the `tanh` function as its activation function.
#
#
# * **(c)** Instantiate a second dense layer called **`dense2`** with 8 neurons. The layer will have the `tanh` function as its activation function.
#
#
# * **(d)** Instantiate a third dense layer called **`dense3`** with 6 neurons. The layer will have the `tanh` activation function.
#
#
# * **(e)** Instantiate a fourth dense layer called **`dense4`** with 3 neurons. The layer will have the `softmax` activation function.

# %%
## Insert your code here

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

inputs = Input(shape = (4,), name = "Input")

dense1 = Dense(units = 10, activation = "tanh", name = "Dense_1")
dense2 = Dense(units = 8, activation = "tanh", name = "Dense_2")
dense3 = Dense(units = 6, activation = "tanh", name = "Dense_3")
dense4 = Dense(units = 3, activation = "softmax", name = "Dense_4")

# %% [markdown]
# * **(f)** Since we are dealing with a **functional** construction, we must apply the different layers of the model one by one, specifying that the first layer will take the input and the output will correspond to the application of the last Dense layer.

# %%
## Insert your code here

# %%
x=dense1(inputs)
x=dense2(x)
x=dense3(x)
outputs=dense4(x)

# %% [markdown]
# > The following commands allow you to finalize the definition of the model and display its structure.

# %%
model = Model(inputs = inputs, outputs = outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 4)]               0
#
#  Dense_1 (Dense)             (None, 10)                50
#
#  Dense_2 (Dense)             (None, 8)                 88
#
#  Dense_3 (Dense)             (None, 6)                 54
#
#  Dense_4 (Dense)             (None, 3)                 21
#
# =================================================================
# Total params: 213
# Trainable params: 213
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * **(g)** Compile the model, with the loss function: **`“sparse_categorical_crossentropy”`**, suitable for multi-class classification. Set the optimizer: **`‘adam’`** and the metric: **`[“accuracy”]`**

# %%
## Insert your code here

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = "adam",
              metrics = ["accuracy"])

# %% [markdown]
# > We can finally train our model on the data. This is done in the same style as *scikit-learn*:
# >
# > ```python
# > model.fit (X, y, epochs = n, batch_size = 32, validation_split = p)
# >```
# >
# >* The **`batch_size`** argument defines the number of training samples that will be used to calculate the gradient of the loss function. This means that not all the data is used at once, which has beneficial effects such as regularization and faster training time.
# >
# > * The **`epochs`** argument indicates the number of passes through the dataset that we will perform during the optimization process. There are therefore several optimization steps at each epoch, and each of these steps uses a **`batch_size`** number of data points. Training with a **high number** of epochs can lead to **overfitting** or **overlearning**, while a **low** number of epochs leads to **underfitting**.
# >
# > The following illustration provides a clearer view of the epochs and batch_size arguments based on our dataset:
# >
# ><img src=https://datascientest.fr/train/assets/masterclass_deeplearning_batch.png style=‘width:250px’>
# >
# > * The **`validation_split`** argument allows us to keep a certain proportion of the dataset as a **validation set**. The model will be **evaluated** on the validation dataset **at the end of each epoch**.
# >
# > We can finally train our model on the data. This is done in the same style as *scikit-learn*:
#
# >
# > Do you remember the Iris dataset from the first notebook? The following widget will illustrate this concept of batch and epoch through the minimization of the loss function of this problem. For each optimization step, gradient descent is performed based on the loss calculated on the selected batch, and this operation is repeated until the entire dataset has been processed: that is, until one epoch has been completed.
# * Run the following cell:

# %%
# %run widget_batch_gradient_descent.py
# Out:
# VBox(children=(HBox(children=(Figure(axes=[Axis(label='Sepal Length', scale=LinearScale(max=4.0, min=-4.0)), A…

# %% [markdown]
# * **(h)** Train the model on “X_train” and “y_train” for **`500`** epochs with a batch size of **`32`** samples and maintaining a validation split of **`0.1`**.

# %%
## Insert your code here

# %%
model.fit(X_train,y_train,epochs=500,batch_size=32,validation_split=0.1)

y_pred = model.predict(X_test)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 2s 101ms/step - loss: 1.0078 - accuracy: 0.3222 - val_loss: 1.0389 - val_accuracy: 0.2000
# Epoch 2/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.9903 - accuracy: 0.4111 - val_loss: 1.0141 - val_accuracy: 0.6000
# Epoch 3/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.9709 - accuracy: 0.6778 - val_loss: 0.9937 - val_accuracy: 0.8000
# Epoch 4/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9561 - accuracy: 0.7222 - val_loss: 0.9739 - val_accuracy: 0.7000
# Epoch 5/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9409 - accuracy: 0.7000 - val_loss: 0.9561 - val_accuracy: 0.8000
# Epoch 6/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9270 - accuracy: 0.6667 - val_loss: 0.9402 - val_accuracy: 0.8000
# Epoch 7/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9144 - accuracy: 0.6222 - val_loss: 0.9264 - val_accuracy: 0.7000
# Epoch 8/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9020 - accuracy: 0.6667 - val_loss: 0.9137 - val_accuracy: 0.6000
# Epoch 9/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8902 - accuracy: 0.6667 - val_loss: 0.9019 - val_accuracy: 0.6000
# Epoch 10/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8780 - accuracy: 0.6667 - val_loss: 0.8911 - val_accuracy: 0.6000
# Epoch 11/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8657 - accuracy: 0.6667 - val_loss: 0.8811 - val_accuracy: 0.6000
# Epoch 12/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8535 - accuracy: 0.6667 - val_loss: 0.8720 - val_accuracy: 0.6000
# Epoch 13/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8406 - accuracy: 0.6556 - val_loss: 0.8633 - val_accuracy: 0.6000
# Epoch 14/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8269 - accuracy: 0.6556 - val_loss: 0.8546 - val_accuracy: 0.6000
# Epoch 15/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8134 - accuracy: 0.6556 - val_loss: 0.8457 - val_accuracy: 0.6000
# Epoch 16/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7998 - accuracy: 0.6556 - val_loss: 0.8367 - val_accuracy: 0.6000
# Epoch 17/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7863 - accuracy: 0.6556 - val_loss: 0.8276 - val_accuracy: 0.6000
# Epoch 18/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7721 - accuracy: 0.6556 - val_loss: 0.8178 - val_accuracy: 0.6000
# Epoch 19/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7578 - accuracy: 0.6556 - val_loss: 0.8074 - val_accuracy: 0.6000
# Epoch 20/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7443 - accuracy: 0.6667 - val_loss: 0.7967 - val_accuracy: 0.6000
# Epoch 21/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7312 - accuracy: 0.6667 - val_loss: 0.7859 - val_accuracy: 0.6000
# Epoch 22/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7166 - accuracy: 0.6667 - val_loss: 0.7742 - val_accuracy: 0.6000
# Epoch 23/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7032 - accuracy: 0.6667 - val_loss: 0.7623 - val_accuracy: 0.6000
# Epoch 24/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6897 - accuracy: 0.6667 - val_loss: 0.7499 - val_accuracy: 0.6000
# Epoch 25/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6769 - accuracy: 0.6667 - val_loss: 0.7377 - val_accuracy: 0.6000
# Epoch 26/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6637 - accuracy: 0.6667 - val_loss: 0.7255 - val_accuracy: 0.6000
# Epoch 27/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6518 - accuracy: 0.6667 - val_loss: 0.7135 - val_accuracy: 0.6000
# Epoch 28/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6391 - accuracy: 0.6556 - val_loss: 0.7017 - val_accuracy: 0.6000
# Epoch 29/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6275 - accuracy: 0.6556 - val_loss: 0.6903 - val_accuracy: 0.6000
# Epoch 30/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6168 - accuracy: 0.6556 - val_loss: 0.6795 - val_accuracy: 0.6000
# Epoch 31/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6061 - accuracy: 0.6556 - val_loss: 0.6693 - val_accuracy: 0.6000
# Epoch 32/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.5962 - accuracy: 0.6556 - val_loss: 0.6595 - val_accuracy: 0.6000
# Epoch 33/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5869 - accuracy: 0.6667 - val_loss: 0.6504 - val_accuracy: 0.6000
# Epoch 34/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5779 - accuracy: 0.6667 - val_loss: 0.6416 - val_accuracy: 0.6000
# Epoch 35/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5695 - accuracy: 0.6778 - val_loss: 0.6332 - val_accuracy: 0.6000
# Epoch 36/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5615 - accuracy: 0.6778 - val_loss: 0.6253 - val_accuracy: 0.6000
# Epoch 37/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5539 - accuracy: 0.6889 - val_loss: 0.6179 - val_accuracy: 0.6000
# Epoch 38/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5469 - accuracy: 0.7111 - val_loss: 0.6108 - val_accuracy: 0.6000
# Epoch 39/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5399 - accuracy: 0.7222 - val_loss: 0.6040 - val_accuracy: 0.8000
# Epoch 40/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.5339 - accuracy: 0.7444 - val_loss: 0.5976 - val_accuracy: 0.9000
# Epoch 41/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5275 - accuracy: 0.7778 - val_loss: 0.5916 - val_accuracy: 0.9000
# Epoch 42/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5218 - accuracy: 0.8111 - val_loss: 0.5858 - val_accuracy: 0.9000
# Epoch 43/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5164 - accuracy: 0.8222 - val_loss: 0.5803 - val_accuracy: 0.9000
# Epoch 44/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5111 - accuracy: 0.8444 - val_loss: 0.5748 - val_accuracy: 0.9000
# Epoch 45/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5061 - accuracy: 0.8667 - val_loss: 0.5694 - val_accuracy: 0.9000
# Epoch 46/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5013 - accuracy: 0.8778 - val_loss: 0.5642 - val_accuracy: 0.9000
# Epoch 47/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4965 - accuracy: 0.9000 - val_loss: 0.5589 - val_accuracy: 1.0000
# Epoch 48/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4921 - accuracy: 0.9111 - val_loss: 0.5538 - val_accuracy: 1.0000
# Epoch 49/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4875 - accuracy: 0.9333 - val_loss: 0.5485 - val_accuracy: 1.0000
# Epoch 50/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4829 - accuracy: 0.9444 - val_loss: 0.5433 - val_accuracy: 1.0000
# Epoch 51/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4784 - accuracy: 0.9444 - val_loss: 0.5381 - val_accuracy: 1.0000
# Epoch 52/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4740 - accuracy: 0.9444 - val_loss: 0.5328 - val_accuracy: 1.0000
# Epoch 53/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4701 - accuracy: 0.9556 - val_loss: 0.5273 - val_accuracy: 1.0000
# Epoch 54/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4653 - accuracy: 0.9556 - val_loss: 0.5220 - val_accuracy: 1.0000
# Epoch 55/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4606 - accuracy: 0.9556 - val_loss: 0.5166 - val_accuracy: 1.0000
# Epoch 56/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4561 - accuracy: 0.9556 - val_loss: 0.5114 - val_accuracy: 1.0000
# Epoch 57/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4516 - accuracy: 0.9556 - val_loss: 0.5057 - val_accuracy: 1.0000
# Epoch 58/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4470 - accuracy: 0.9556 - val_loss: 0.5000 - val_accuracy: 1.0000
# Epoch 59/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4422 - accuracy: 0.9556 - val_loss: 0.4940 - val_accuracy: 1.0000
# Epoch 60/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4374 - accuracy: 0.9556 - val_loss: 0.4880 - val_accuracy: 1.0000
# Epoch 61/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4324 - accuracy: 0.9556 - val_loss: 0.4820 - val_accuracy: 1.0000
# Epoch 62/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4279 - accuracy: 0.9556 - val_loss: 0.4756 - val_accuracy: 1.0000
# Epoch 63/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4225 - accuracy: 0.9667 - val_loss: 0.4696 - val_accuracy: 1.0000
# Epoch 64/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4174 - accuracy: 0.9667 - val_loss: 0.4633 - val_accuracy: 1.0000
# Epoch 65/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4118 - accuracy: 0.9667 - val_loss: 0.4572 - val_accuracy: 1.0000
# Epoch 66/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4065 - accuracy: 0.9667 - val_loss: 0.4509 - val_accuracy: 1.0000
# Epoch 67/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4011 - accuracy: 0.9667 - val_loss: 0.4440 - val_accuracy: 1.0000
# Epoch 68/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3952 - accuracy: 0.9667 - val_loss: 0.4371 - val_accuracy: 1.0000
# Epoch 69/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3895 - accuracy: 0.9667 - val_loss: 0.4302 - val_accuracy: 1.0000
# Epoch 70/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3837 - accuracy: 0.9667 - val_loss: 0.4227 - val_accuracy: 1.0000
# Epoch 71/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3781 - accuracy: 0.9667 - val_loss: 0.4149 - val_accuracy: 1.0000
# Epoch 72/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3719 - accuracy: 0.9667 - val_loss: 0.4079 - val_accuracy: 1.0000
# Epoch 73/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3658 - accuracy: 0.9667 - val_loss: 0.4018 - val_accuracy: 1.0000
# Epoch 74/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3597 - accuracy: 0.9778 - val_loss: 0.3953 - val_accuracy: 1.0000
# Epoch 75/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3529 - accuracy: 0.9778 - val_loss: 0.3872 - val_accuracy: 1.0000
# Epoch 76/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3477 - accuracy: 0.9778 - val_loss: 0.3778 - val_accuracy: 1.0000
# Epoch 77/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3405 - accuracy: 0.9778 - val_loss: 0.3707 - val_accuracy: 1.0000
# Epoch 78/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3341 - accuracy: 0.9778 - val_loss: 0.3628 - val_accuracy: 1.0000
# Epoch 79/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3281 - accuracy: 0.9778 - val_loss: 0.3558 - val_accuracy: 1.0000
# Epoch 80/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3217 - accuracy: 0.9778 - val_loss: 0.3492 - val_accuracy: 1.0000
# Epoch 81/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3161 - accuracy: 0.9778 - val_loss: 0.3431 - val_accuracy: 1.0000
# Epoch 82/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3101 - accuracy: 0.9778 - val_loss: 0.3356 - val_accuracy: 1.0000
# Epoch 83/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3052 - accuracy: 0.9778 - val_loss: 0.3273 - val_accuracy: 1.0000
# Epoch 84/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2994 - accuracy: 0.9778 - val_loss: 0.3218 - val_accuracy: 1.0000
# Epoch 85/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2943 - accuracy: 0.9778 - val_loss: 0.3163 - val_accuracy: 1.0000
# Epoch 86/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2889 - accuracy: 0.9778 - val_loss: 0.3084 - val_accuracy: 1.0000
# Epoch 87/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2841 - accuracy: 0.9778 - val_loss: 0.3019 - val_accuracy: 1.0000
# Epoch 88/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2792 - accuracy: 0.9778 - val_loss: 0.2966 - val_accuracy: 1.0000
# Epoch 89/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2745 - accuracy: 0.9778 - val_loss: 0.2918 - val_accuracy: 1.0000
# Epoch 90/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2702 - accuracy: 0.9778 - val_loss: 0.2862 - val_accuracy: 1.0000
# Epoch 91/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2659 - accuracy: 0.9778 - val_loss: 0.2813 - val_accuracy: 1.0000
# Epoch 92/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2616 - accuracy: 0.9778 - val_loss: 0.2759 - val_accuracy: 1.0000
# Epoch 93/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2577 - accuracy: 0.9778 - val_loss: 0.2716 - val_accuracy: 1.0000
# Epoch 94/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2534 - accuracy: 0.9778 - val_loss: 0.2649 - val_accuracy: 1.0000
# Epoch 95/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2499 - accuracy: 0.9778 - val_loss: 0.2581 - val_accuracy: 1.0000
# Epoch 96/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2460 - accuracy: 0.9778 - val_loss: 0.2532 - val_accuracy: 1.0000
# Epoch 97/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2422 - accuracy: 0.9778 - val_loss: 0.2496 - val_accuracy: 1.0000
# Epoch 98/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2386 - accuracy: 0.9778 - val_loss: 0.2465 - val_accuracy: 1.0000
# Epoch 99/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2351 - accuracy: 0.9778 - val_loss: 0.2425 - val_accuracy: 1.0000
# Epoch 100/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2317 - accuracy: 0.9778 - val_loss: 0.2368 - val_accuracy: 1.0000
# Epoch 101/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2282 - accuracy: 0.9778 - val_loss: 0.2321 - val_accuracy: 1.0000
# Epoch 102/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2253 - accuracy: 0.9778 - val_loss: 0.2291 - val_accuracy: 1.0000
# Epoch 103/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2223 - accuracy: 0.9778 - val_loss: 0.2242 - val_accuracy: 1.0000
# Epoch 104/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2190 - accuracy: 0.9778 - val_loss: 0.2218 - val_accuracy: 1.0000
# Epoch 105/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2161 - accuracy: 0.9778 - val_loss: 0.2176 - val_accuracy: 1.0000
# Epoch 106/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2131 - accuracy: 0.9778 - val_loss: 0.2122 - val_accuracy: 1.0000
# Epoch 107/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2103 - accuracy: 0.9778 - val_loss: 0.2084 - val_accuracy: 1.0000
# Epoch 108/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2081 - accuracy: 0.9778 - val_loss: 0.2043 - val_accuracy: 1.0000
# Epoch 109/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2049 - accuracy: 0.9778 - val_loss: 0.2039 - val_accuracy: 1.0000
# Epoch 110/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2021 - accuracy: 0.9778 - val_loss: 0.2011 - val_accuracy: 1.0000
# Epoch 111/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1996 - accuracy: 0.9778 - val_loss: 0.1972 - val_accuracy: 1.0000
# Epoch 112/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1971 - accuracy: 0.9778 - val_loss: 0.1931 - val_accuracy: 1.0000
# Epoch 113/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1947 - accuracy: 0.9778 - val_loss: 0.1889 - val_accuracy: 1.0000
# Epoch 114/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1926 - accuracy: 0.9778 - val_loss: 0.1838 - val_accuracy: 1.0000
# Epoch 115/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1905 - accuracy: 0.9778 - val_loss: 0.1809 - val_accuracy: 1.0000
# Epoch 116/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1877 - accuracy: 0.9778 - val_loss: 0.1816 - val_accuracy: 1.0000
# Epoch 117/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1855 - accuracy: 0.9778 - val_loss: 0.1803 - val_accuracy: 1.0000
# Epoch 118/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1838 - accuracy: 0.9778 - val_loss: 0.1764 - val_accuracy: 1.0000
# Epoch 119/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1825 - accuracy: 0.9778 - val_loss: 0.1717 - val_accuracy: 1.0000
# Epoch 120/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1795 - accuracy: 0.9778 - val_loss: 0.1711 - val_accuracy: 1.0000
# Epoch 121/500
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1798 - accuracy: 0.9778 - val_loss: 0.1659 - val_accuracy: 1.0000
# Epoch 122/500
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1758 - accuracy: 0.9778 - val_loss: 0.1676 - val_accuracy: 1.0000
# Epoch 123/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1742 - accuracy: 0.9778 - val_loss: 0.1654 - val_accuracy: 1.0000
# Epoch 124/500
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1723 - accuracy: 0.9778 - val_loss: 0.1601 - val_accuracy: 1.0000
# Epoch 125/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1700 - accuracy: 0.9778 - val_loss: 0.1570 - val_accuracy: 1.0000
# Epoch 126/500
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1686 - accuracy: 0.9778 - val_loss: 0.1552 - val_accuracy: 1.0000
# Epoch 127/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1668 - accuracy: 0.9778 - val_loss: 0.1522 - val_accuracy: 1.0000
# Epoch 128/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1653 - accuracy: 0.9778 - val_loss: 0.1498 - val_accuracy: 1.0000
# Epoch 129/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1633 - accuracy: 0.9778 - val_loss: 0.1501 - val_accuracy: 1.0000
# Epoch 130/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1618 - accuracy: 0.9778 - val_loss: 0.1486 - val_accuracy: 1.0000
# Epoch 131/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1605 - accuracy: 0.9778 - val_loss: 0.1469 - val_accuracy: 1.0000
# Epoch 132/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1588 - accuracy: 0.9778 - val_loss: 0.1437 - val_accuracy: 1.0000
# Epoch 133/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1573 - accuracy: 0.9778 - val_loss: 0.1399 - val_accuracy: 1.0000
# Epoch 134/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1558 - accuracy: 0.9778 - val_loss: 0.1381 - val_accuracy: 1.0000
# Epoch 135/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1545 - accuracy: 0.9778 - val_loss: 0.1362 - val_accuracy: 1.0000
# Epoch 136/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1529 - accuracy: 0.9778 - val_loss: 0.1363 - val_accuracy: 1.0000
# Epoch 137/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1524 - accuracy: 0.9778 - val_loss: 0.1367 - val_accuracy: 1.0000
# Epoch 138/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1513 - accuracy: 0.9778 - val_loss: 0.1312 - val_accuracy: 1.0000
# Epoch 139/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1509 - accuracy: 0.9778 - val_loss: 0.1318 - val_accuracy: 1.0000
# Epoch 140/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1494 - accuracy: 0.9778 - val_loss: 0.1257 - val_accuracy: 1.0000
# Epoch 141/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1476 - accuracy: 0.9778 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 142/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1454 - accuracy: 0.9778 - val_loss: 0.1251 - val_accuracy: 1.0000
# Epoch 143/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1443 - accuracy: 0.9778 - val_loss: 0.1242 - val_accuracy: 1.0000
# Epoch 144/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1428 - accuracy: 0.9778 - val_loss: 0.1217 - val_accuracy: 1.0000
# Epoch 145/500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1419 - accuracy: 0.9778 - val_loss: 0.1206 - val_accuracy: 1.0000
# Epoch 146/500
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1407 - accuracy: 0.9778 - val_loss: 0.1190 - val_accuracy: 1.0000
# Epoch 147/500
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1397 - accuracy: 0.9778 - val_loss: 0.1170 - val_accuracy: 1.0000
# Epoch 148/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1389 - accuracy: 0.9778 - val_loss: 0.1154 - val_accuracy: 1.0000
# Epoch 149/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1375 - accuracy: 0.9778 - val_loss: 0.1165 - val_accuracy: 1.0000
# Epoch 150/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1385 - accuracy: 0.9778 - val_loss: 0.1193 - val_accuracy: 1.0000
# Epoch 151/500
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1359 - accuracy: 0.9667 - val_loss: 0.1160 - val_accuracy: 1.0000
# Epoch 152/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1347 - accuracy: 0.9778 - val_loss: 0.1113 - val_accuracy: 1.0000
# Epoch 153/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1342 - accuracy: 0.9778 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 154/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1328 - accuracy: 0.9778 - val_loss: 0.1069 - val_accuracy: 1.0000
# Epoch 155/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1316 - accuracy: 0.9778 - val_loss: 0.1075 - val_accuracy: 1.0000
# Epoch 156/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1311 - accuracy: 0.9778 - val_loss: 0.1099 - val_accuracy: 1.0000
# Epoch 157/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1298 - accuracy: 0.9778 - val_loss: 0.1082 - val_accuracy: 1.0000
# Epoch 158/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1291 - accuracy: 0.9778 - val_loss: 0.1053 - val_accuracy: 1.0000
# Epoch 159/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1278 - accuracy: 0.9778 - val_loss: 0.1034 - val_accuracy: 1.0000
# Epoch 160/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1273 - accuracy: 0.9778 - val_loss: 0.1004 - val_accuracy: 1.0000
# Epoch 161/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1273 - accuracy: 0.9778 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 162/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1254 - accuracy: 0.9778 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 163/500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1243 - accuracy: 0.9778 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 164/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1236 - accuracy: 0.9778 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 165/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1232 - accuracy: 0.9778 - val_loss: 0.0999 - val_accuracy: 1.0000
# Epoch 166/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1226 - accuracy: 0.9778 - val_loss: 0.0965 - val_accuracy: 1.0000
# Epoch 167/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1225 - accuracy: 0.9778 - val_loss: 0.0939 - val_accuracy: 1.0000
# Epoch 168/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.
- val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 477/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0581 - accuracy: 0.9889 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 478/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0589 - accuracy: 0.9778 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 479/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0582 - accuracy: 0.9889 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 480/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0591 - accuracy: 0.9889 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 481/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0578 - accuracy: 0.9889 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 482/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0578 - accuracy: 0.9778 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 483/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0599 - accuracy: 0.9889 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 484/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0570 - accuracy: 0.9889 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 485/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0587 - accuracy: 0.9889 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 486/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0578 - accuracy: 0.9889 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 487/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0584 - accuracy: 0.9889 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 488/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0580 - accuracy: 0.9889 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 489/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0568 - accuracy: 0.9889 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 490/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0586 - accuracy: 0.9889 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 491/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0574 - accuracy: 0.9778 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 492/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0567 - accuracy: 0.9889 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 493/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0563 - accuracy: 0.9889 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 494/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0567 - accuracy: 0.9889 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 495/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0571 - accuracy: 0.9889 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 496/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0574 - accuracy: 0.9889 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 497/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0567 - accuracy: 0.9889 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 498/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0564 - accuracy: 0.9889 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 499/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0565 - accuracy: 0.9889 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 500/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0566 - accuracy: 0.9778 - val_loss: 0.0265 - val_accuracy: 1.0000
# 2/2 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Model performance
#
# > We now want to diagnose our model. To do this, we will calculate a confusion matrix on the test sample.
# >
# > However, if we try to predict the class of the test sample, the model's **`predict`** method returns a **probability vector** where each element is the probability of belonging to the class corresponding to its index.
# >
# > To use the `classification_report` function from the **metrics** submodule of **scikit-learn**, the prediction vector and the actual class vector must be composed of integers.
# >
# > We will then use the `argmax` method of a **numpy** array to find out which class the binary vectors and probability vectors correspond to.
#
# * **(a)** Predict the classes of the **X_test** sample using the model's `predict` method. Store the result in an array named **test_pred**.
#
#
# * **(b)** Apply the `argmax` method to the **test_pred** arrays to obtain vectors of integers corresponding to the predicted and actual classes. You will need to pass the argument ‘axis = 1’ so that argmax is calculated on the columns and not the rows. Store the outputs of the `argmax` method calls in an array named **test_pred_class** and the actual values in **y_test_class**.

# %%
## Insert your code here

# %%
test_pred = model.predict(X_test)


y_test_class = y_test
y_pred_class = np.argmax(test_pred,axis=1)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %% [markdown]
# * **(c)** Display a detailed evaluation report of the model's performance using the `classification_report` function of the **metrics** submodule of **scikit-learn**.

# %%
## Insert your code here

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.94      1.00      0.97        15
#            2       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
#
# [[19  0  0]
#  [ 0 15  0]
#  [ 0  1 15]]

# %% [markdown]
# >Comparativement au modèle avec un seul perceptron, les résultats de classification semble nettemenent meilleurs avec plusieurs couches Denses.
# Compared to the single perceptron model, the classification results appear to be significantly better with multiple dense layers.
#
# <hr style="border-width:2px;border-color:#75DFC1">
# <h2 style = “text-align:center” > Key takeaways </h2>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# > * The **multilayer perceptron** algorithm is particularly effective for **classification** problems.
# > * The **sparse categorical crossentropy** loss function is used for classification problems.
# > * You can easily build an **MLP** on **Keras** using a **sequential** construction when the architecture is simple. The **functional** construction is more versatile.
# > * You train the neural network by traversing it using the **`batch_size`** and **`epoch`** parameters.
#
# >You can find all the features of **`keras`** in **`tensorflow.keras`**. In particular, there are “neural layers” in **`tensorflow.keras.layers`**:
# >
# > | Definition          | Class               |
# > | :-----------------: |:--------------------:|
# > | Dense layer         | `Dense`              |
# > | Convolution 2D      | `Conv2D`             |
# > | Dropout             | `Dropout`            |
# > | Batch Normalization | `BatchNormalization` |
# > | Average Pooling 2D  | `AveragePooling2D`   |
# > | Flatten             | `Flatten`            |
# > | RNN                 | `RNN`                |
# > | LSTM                | `LSTM`               |
# > | GRU                 | `GRU`                |
