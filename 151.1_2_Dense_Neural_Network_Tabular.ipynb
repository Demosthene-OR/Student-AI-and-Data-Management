# %% [markdown]
# <center><img src="https://datascientest.fr/train/assets/logo_datascientest.png" style="height:150px"></center>
#
#
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Introduction au Deep Learning avec Keras</h1></center>
# <center><h2>Prédictions à l'aide de Dense Neural Network sur des données tabulaires</h2></center>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# ## Contexte et Objectif
#
# >Comme évoqué précedemment, l'algorithme du perceptron simple n'a pas réellement d'intérêt. Il est préférable de considérer un perceptron multicouche pour observer des résultats intéressants. Le GIF suivant en est une illustration :
# >
# ><img src='https://assets-datascientest.s3-eu-west-1.amazonaws.com/notebooks/masterclass_deeplearning_debutant_intro_dense.gif' style='width:400px'>
# >
# >**Nous allons à présent nous pencher sur un exemple de modèle de Perceptron multicouche sur le Dataset bien connu IRIS.** Pour rappel, ce jeu de données est le plus réputé pour des projets de reconnaissance d'espèces. Il contient des informations visuelles sur 3 espèces d'iris décrites par 50 observations chacunes. L'objectif est donc de reconnaître la fleur d'iris à partir de certaines mesures caractéristiques regroupées dans des données **tabulaires**.
#
# * **(a)** Exécuter la cellule suivante pour importer les packages nécéssaires :

# %%
import numpy as np # Pour la manipulation de tableaux

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from tensorflow.keras.layers import Input, Dense #Pour instancier une couche Dense et une d'Input
from tensorflow.keras.models import Model

# %% [markdown]
# ## Chargement des données et preprocessing
#
# * **(b)** Lire le fichier **Iris.csv** dans un dataframe df, spécifier la colonne **Id** qui doit contenir les index, et afficher les 5 premières lignes.

# %%
## Insérez votre code ici

# %%
df=pd.read_csv('Iris.csv', index_col = 'Id')
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# * **(c)** Séparer les variables explicatives de la variable cible.
# * **(d)** Encoder la variable cible, **`'Species'`** en fonction de chaque espèce.

# %%
## Insérez votre code ici

# %%
#Splitting the data into training and test test
X = df.iloc[:,0:4].values
y = df.iloc[:,4].values

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
Y = encoder.fit_transform(y)

# %% [markdown]
# * **(e)** Séparer les données en un jeu d'entraînement et test. Le jeu de test pèsera pour **un tiers** du jeu de données.

# %%
## Insérez votre code ici

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.33,random_state=42)

# %% [markdown]
# ## Multi Layer Perceptron
#
# > Le modèle Perceptron multicouche est une **séquence de couches Perceptron** dont l'entrée est la sortie de la **couche précédente**.
# >
# > Considérons un modèle Perceptron à 3 couches. Pour un vecteur d'entrée donné $x$, la sortie de la première couche est :
# >
# > $$ H_1 = \mathrm{Layer_1}(x) $$
# >
# > Ensuite, le vecteur $H_1$ est donné en entrée à la deuxième couche :
# >
# > $$ H_2 = \mathrm{Layer_2}(H_1) $$
# >
# > Enfin, le vecteur $H_2$ est donné en entrée à la troisième couche pour obtenir la sortie finale du modèle :
# >
# > $$ O = \mathrm{Layer_3}(H_2) $$
# >
# > <img src = "https://assets-datascientest.s3-eu-west-1.amazonaws.com/notebooks/perceptron3.png">
# >
# > Les perceptrons multicouches peuvent être construits **sequentiellement** en empilant les couches denses les unes après les autres. Vous rencontrerez parfois cette écriture dans Keras, même si dans ce module nous avons décidé d'utiliser la construction **fonctionnelle** qui est plus versatile et qui s'utilise d'avantage quand on écrit des modèles complexes pouvant avoir une structure non linéaire ou prendre différents inputs.
#
# ## Construction et Entraînement d'un modèle
#
#
#
#
# > Nous allons construire notre modèle en ajoutant couche par couche depuis la couche d'entrée jusqu'à la couche de sortie.
# >
# > La construction d'un modèle avec **Keras** se fait très facilement avec les étapes suivantes:
# >
# >
# >* **Étape 1** : Importer les classes `Input` et `Dense` du sous-module `tensorflow.keras.layers` ainsi que la classe `Model` du sous-module `tensorflow.keras.models`
# >
# >```python
# > from tensorflow.keras... import ...
# >```
# >
# > * **Étape 2** : Instancier une couche d'entrée qui contient les dimensions de nos données en entrée
# >
# >```python
# > inputs = Input(shape = (..), name = "Input")
# >```
# >
# > * **Étape 3** : Instancier les couches qui composeront le modèle avec leur constructeur. Pour instancier une couche dense, il faut utiliser le constructeur `Dense`, que nous avons importé.
# >
# >```python
# > dense1 = Dense(units = ..., activation = "...", name = "Couche_1")
# >```
# >
# > * **Étape 4** : Appliquer les couches une à une (construction **fonctionnelle**).
# >
# >```python
# > x = dense1(inputs)
# > x = dense2(x)
# > ...
# >```
# >
# > L'instanciation de couches contient plusieurs nuances:
# >
# > * La première couche que nous allons ajouter au modèle doit être instanciée **en précisant les dimensions du vecteur d'entrée** avec le paramètre **shape**. Cette précision n'est pas nécessaire pour les couches suivantes.
# >
# >
# > * Le **nombre de neurones** dans une couche se définit avec le paramètre **units**.
# >
# >
# > * Pour ajouter une fonction activation à une couche de neurones, on peut soit instancier une couche d'activation puis l'ajouter au modèle, ou bien définir la fonction d'activation dans le paramètre **activation** du constructeur d'une couche.
# >
#
# * **(a)** Instancier une couche inputs, avec pour dimension le nombre de variables explicatives du modèle.
#
#
# * **(b)** Instancier une couche dense appelée **`dense1`** avec 10 neurones. Cette couche aura comme fonction d'activation la fonction `tanh`.
#
#
# * **(c)** Instancier une deuxième couche dense appelée **`dense2`** avec 8 neurones. La couche aura comme fonction d'activation `tanh`.
#
#
# * **(d)** Instancier une troisième couche dense appelée **`dense3`** avec 6 neurones. La couche aura comme fonction d'activation `tanh`.
#
#
# * **(e)** Instancier une quatrième couche dense appelée **`dense4`** avec 3 neurones. La couche aura comme fonction d'activation `softmax`.

# %%
## Insérez votre code ici

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

inputs = Input(shape = (4), name = "Input")

dense1 = Dense(units = 10, activation = "tanh", name = "Dense_1")
dense2 = Dense(units = 8, activation = "tanh", name = "Dense_2")
dense3 = Dense(units = 6, activation = "tanh", name = "Dense_3")
dense4 = Dense(units = 3, activation = "softmax", name = "Dense_4")

# %% [markdown]
# * **(f)** Comme nous sommes dans une construction **fonctionnelle**, il faut appliquer une à une les différentes couches du modèle en précisant que la première couche prendra en entrée l'input et l'output correspondra à l'application de la derniere couche Dense.

# %%
## Insérez votre code ici

# %%
x=dense1(inputs)
x=dense2(x)
x=dense3(x)
outputs=dense4(x)

# %% [markdown]
# > Les commandes suivantes permettent de finaliser la définition du modèle et d'en afficher la structure.

# %%
model = Model(inputs = inputs, outputs = outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 4)]               0
#
#  Dense_1 (Dense)             (None, 10)                50
#
#  Dense_2 (Dense)             (None, 8)                 88
#
#  Dense_3 (Dense)             (None, 6)                 54
#
#  Dense_4 (Dense)             (None, 3)                 21
#
# =================================================================
# Total params: 213
# Trainable params: 213
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * **(g)** Compiler le modèle, avec comme fonction de perte: **`"sparse_categorical_crossentropy"`**, adaptée à la classification à multi-classe. Définir l'optimiseur : **`"adam"`** et la métrique : **`["accuracy"]`**

# %%
## Insérez votre code ici

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = "adam",
              metrics = ["accuracy"])

# %% [markdown]
# >Nous pouvons enfin entrainer notre modèle aux données. Ceci est fait dans le même style que *scikit-learn* :
# >
# >```python
# > model.fit (X, y, epochs = n, batch_size = 32, validation_split = p)
# >```
# >
# >* L'argument **`batch_size`** définira le nombre d'échantillons d'apprentissage qui seront utilisés pour calculer le gradient de la fonction de perte. Cela permet de ne pas utiliser toutes les données d'un seul coup, cela a des effets bénéfiques tels que la régularisation et l'accélération du temps d'entraînement.
# >
# > * L'argument **`epochs`** indique lui le nombre de passages à travers l'ensemble de données que nous allons effectuer pendant le processus d'optimisation. Il y a donc plusieurs étapes d'optimisation à chaque epoch, et chacune de ces étapes utilise un nombre **`batch_size`** de données. Un entraînement avec un **nombre élevé** d'epochs peut induire un **surajustement** ou **surapprentissage** tandis qu'un **faible** nombre d'epochs induit un **sous-ajustement**.
# >
# > L'illustration suivante permet de mieux visualiser les arguments epochs et batch_size en fonction de notre jeu de données :
# >
# ><img src=https://datascientest.fr/train/assets/masterclass_deeplearning_batch.png style='width:250px'>
# >
# > * L'argument **`validation_split`** nous permet de conserver une certaine proportion de l'ensemble de données comme un **ensemble de validation**. Le modèle sera **évalué** sur l'ensemble de données de validation **à la fin de chaque epoch**.
# >
# > Vous souvenez-vous du jeu de données d'Iris du 1er notebook ? Le widget suivant va illustrer ce concept de batch et epoch à travers la minimisation de la fonction de perte de ce problème. Pour chaque étape d'optimisation, la descente de gradient est effectuée à partir de la loss calculée sur le batch choisi, et cette opération se répète jusqu'à avoir parcouru tout le dataset : c'est à dire jusqu'à avoir effectué une epoch.
# * Exécuter la cellule suivante :

# %%
# %run widget_batch_gradient_descent.py
# Out:
# VBox(children=(HBox(children=(Figure(axes=[Axis(label='Sepal Length', scale=LinearScale(max=4.0, min=-4.0)), A…

# %% [markdown]
# * **(h)** Entraîner le modèle sur «X_train» et «y_train» pour les epochs **`500`** avec une taille de lot de **`32`** échantillons et en conservant un fractionnement de validation de **`0,1`** .

# %%
## Insérez votre code ici

# %%
model.fit(X_train,y_train,epochs=500,batch_size=32,validation_split=0.1)

y_pred = model.predict(X_test)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 3s 79ms/step - loss: 1.1972 - accuracy: 0.3333 - val_loss: 1.2347 - val_accuracy: 0.4000
# Epoch 2/500
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1768 - accuracy: 0.3333 - val_loss: 1.2154 - val_accuracy: 0.4000
# Epoch 3/500
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1547 - accuracy: 0.3333 - val_loss: 1.1972 - val_accuracy: 0.4000
# Epoch 4/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1368 - accuracy: 0.3333 - val_loss: 1.1807 - val_accuracy: 0.4000
# Epoch 5/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1227 - accuracy: 0.3333 - val_loss: 1.1652 - val_accuracy: 0.4000
# Epoch 6/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1071 - accuracy: 0.3222 - val_loss: 1.1518 - val_accuracy: 0.4000
# Epoch 7/500
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0995 - accuracy: 0.3111 - val_loss: 1.1396 - val_accuracy: 0.4000
# Epoch 8/500
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0885 - accuracy: 0.3778 - val_loss: 1.1300 - val_accuracy: 0.3000
# Epoch 9/500
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0781 - accuracy: 0.4667 - val_loss: 1.1216 - val_accuracy: 0.2000
# Epoch 10/500
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0711 - accuracy: 0.5111 - val_loss: 1.1142 - val_accuracy: 0.2000
# Epoch 11/500
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0645 - accuracy: 0.5778 - val_loss: 1.1067 - val_accuracy: 0.2000
# Epoch 12/500
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0569 - accuracy: 0.6222 - val_loss: 1.0992 - val_accuracy: 0.3000
# Epoch 13/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0496 - accuracy: 0.6444 - val_loss: 1.0916 - val_accuracy: 0.3000
# Epoch 14/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0411 - accuracy: 0.6889 - val_loss: 1.0832 - val_accuracy: 0.3000
# Epoch 15/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0318 - accuracy: 0.6667 - val_loss: 1.0745 - val_accuracy: 0.3000
# Epoch 16/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0216 - accuracy: 0.6889 - val_loss: 1.0648 - val_accuracy: 0.3000
# Epoch 17/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0101 - accuracy: 0.6667 - val_loss: 1.0544 - val_accuracy: 0.3000
# Epoch 18/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9975 - accuracy: 0.6667 - val_loss: 1.0432 - val_accuracy: 0.3000
# Epoch 19/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9834 - accuracy: 0.6556 - val_loss: 1.0305 - val_accuracy: 0.3000
# Epoch 20/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9676 - accuracy: 0.6444 - val_loss: 1.0168 - val_accuracy: 0.3000
# Epoch 21/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9516 - accuracy: 0.6333 - val_loss: 1.0030 - val_accuracy: 0.3000
# Epoch 22/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9332 - accuracy: 0.6222 - val_loss: 0.9879 - val_accuracy: 0.2000
# Epoch 23/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9135 - accuracy: 0.6000 - val_loss: 0.9715 - val_accuracy: 0.2000
# Epoch 24/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8923 - accuracy: 0.5889 - val_loss: 0.9538 - val_accuracy: 0.3000
# Epoch 25/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8709 - accuracy: 0.5889 - val_loss: 0.9347 - val_accuracy: 0.3000
# Epoch 26/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8482 - accuracy: 0.6000 - val_loss: 0.9148 - val_accuracy: 0.4000
# Epoch 27/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8258 - accuracy: 0.6333 - val_loss: 0.8944 - val_accuracy: 0.4000
# Epoch 28/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8028 - accuracy: 0.6333 - val_loss: 0.8734 - val_accuracy: 0.6000
# Epoch 29/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7802 - accuracy: 0.6333 - val_loss: 0.8535 - val_accuracy: 0.6000
# Epoch 30/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7571 - accuracy: 0.6444 - val_loss: 0.8328 - val_accuracy: 0.6000
# Epoch 31/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7362 - accuracy: 0.6444 - val_loss: 0.8124 - val_accuracy: 0.6000
# Epoch 32/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7159 - accuracy: 0.6556 - val_loss: 0.7928 - val_accuracy: 0.6000
# Epoch 33/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6976 - accuracy: 0.6667 - val_loss: 0.7736 - val_accuracy: 0.6000
# Epoch 34/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6792 - accuracy: 0.6667 - val_loss: 0.7554 - val_accuracy: 0.6000
# Epoch 35/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6625 - accuracy: 0.6667 - val_loss: 0.7381 - val_accuracy: 0.6000
# Epoch 36/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6473 - accuracy: 0.6667 - val_loss: 0.7223 - val_accuracy: 0.6000
# Epoch 37/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6336 - accuracy: 0.6667 - val_loss: 0.7075 - val_accuracy: 0.6000
# Epoch 38/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6198 - accuracy: 0.6667 - val_loss: 0.6938 - val_accuracy: 0.6000
# Epoch 39/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6082 - accuracy: 0.6667 - val_loss: 0.6811 - val_accuracy: 0.6000
# Epoch 40/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5974 - accuracy: 0.6667 - val_loss: 0.6694 - val_accuracy: 0.6000
# Epoch 41/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5878 - accuracy: 0.6667 - val_loss: 0.6587 - val_accuracy: 0.6000
# Epoch 42/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5782 - accuracy: 0.6667 - val_loss: 0.6489 - val_accuracy: 0.6000
# Epoch 43/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5698 - accuracy: 0.6667 - val_loss: 0.6398 - val_accuracy: 0.6000
# Epoch 44/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5617 - accuracy: 0.6667 - val_loss: 0.6310 - val_accuracy: 0.6000
# Epoch 45/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5541 - accuracy: 0.6667 - val_loss: 0.6226 - val_accuracy: 0.6000
# Epoch 46/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5466 - accuracy: 0.6667 - val_loss: 0.6144 - val_accuracy: 0.6000
# Epoch 47/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5394 - accuracy: 0.6889 - val_loss: 0.6062 - val_accuracy: 0.6000
# Epoch 48/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5320 - accuracy: 0.7111 - val_loss: 0.5981 - val_accuracy: 0.6000
# Epoch 49/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5246 - accuracy: 0.7333 - val_loss: 0.5898 - val_accuracy: 0.6000
# Epoch 50/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5171 - accuracy: 0.7556 - val_loss: 0.5814 - val_accuracy: 0.7000
# Epoch 51/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5094 - accuracy: 0.8222 - val_loss: 0.5730 - val_accuracy: 0.8000
# Epoch 52/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5017 - accuracy: 0.8222 - val_loss: 0.5646 - val_accuracy: 0.8000
# Epoch 53/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4944 - accuracy: 0.8333 - val_loss: 0.5567 - val_accuracy: 0.8000
# Epoch 54/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4867 - accuracy: 0.8333 - val_loss: 0.5483 - val_accuracy: 0.9000
# Epoch 55/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4804 - accuracy: 0.8333 - val_loss: 0.5404 - val_accuracy: 0.8000
# Epoch 56/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4724 - accuracy: 0.8222 - val_loss: 0.5318 - val_accuracy: 0.9000
# Epoch 57/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4652 - accuracy: 0.8444 - val_loss: 0.5236 - val_accuracy: 0.9000
# Epoch 58/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4582 - accuracy: 0.8556 - val_loss: 0.5151 - val_accuracy: 0.9000
# Epoch 59/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4516 - accuracy: 0.8778 - val_loss: 0.5069 - val_accuracy: 0.9000
# Epoch 60/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4444 - accuracy: 0.9000 - val_loss: 0.4984 - val_accuracy: 0.9000
# Epoch 61/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4372 - accuracy: 0.9000 - val_loss: 0.4896 - val_accuracy: 0.9000
# Epoch 62/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4313 - accuracy: 0.9444 - val_loss: 0.4807 - val_accuracy: 1.0000
# Epoch 63/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4236 - accuracy: 0.9444 - val_loss: 0.4724 - val_accuracy: 1.0000
# Epoch 64/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4173 - accuracy: 0.9444 - val_loss: 0.4646 - val_accuracy: 1.0000
# Epoch 65/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4100 - accuracy: 0.9444 - val_loss: 0.4563 - val_accuracy: 1.0000
# Epoch 66/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4027 - accuracy: 0.9444 - val_loss: 0.4466 - val_accuracy: 1.0000
# Epoch 67/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3964 - accuracy: 0.9556 - val_loss: 0.4371 - val_accuracy: 1.0000
# Epoch 68/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3893 - accuracy: 0.9556 - val_loss: 0.4292 - val_accuracy: 1.0000
# Epoch 69/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3812 - accuracy: 0.9556 - val_loss: 0.4202 - val_accuracy: 1.0000
# Epoch 70/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3745 - accuracy: 0.9556 - val_loss: 0.4113 - val_accuracy: 1.0000
# Epoch 71/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3676 - accuracy: 0.9556 - val_loss: 0.4036 - val_accuracy: 1.0000
# Epoch 72/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3603 - accuracy: 0.9556 - val_loss: 0.3951 - val_accuracy: 1.0000
# Epoch 73/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3532 - accuracy: 0.9556 - val_loss: 0.3861 - val_accuracy: 1.0000
# Epoch 74/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3470 - accuracy: 0.9556 - val_loss: 0.3772 - val_accuracy: 1.0000
# Epoch 75/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3400 - accuracy: 0.9556 - val_loss: 0.3694 - val_accuracy: 1.0000
# Epoch 76/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3336 - accuracy: 0.9667 - val_loss: 0.3612 - val_accuracy: 1.0000
# Epoch 77/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3272 - accuracy: 0.9667 - val_loss: 0.3536 - val_accuracy: 1.0000
# Epoch 78/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3220 - accuracy: 0.9667 - val_loss: 0.3457 - val_accuracy: 1.0000
# Epoch 79/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3161 - accuracy: 0.9667 - val_loss: 0.3394 - val_accuracy: 1.0000
# Epoch 80/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3116 - accuracy: 0.9556 - val_loss: 0.3316 - val_accuracy: 1.0000
# Epoch 81/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3052 - accuracy: 0.9667 - val_loss: 0.3256 - val_accuracy: 1.0000
# Epoch 82/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2996 - accuracy: 0.9667 - val_loss: 0.3193 - val_accuracy: 1.0000
# Epoch 83/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2946 - accuracy: 0.9667 - val_loss: 0.3127 - val_accuracy: 1.0000
# Epoch 84/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2895 - accuracy: 0.9667 - val_loss: 0.3066 - val_accuracy: 1.0000
# Epoch 85/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2851 - accuracy: 0.9667 - val_loss: 0.3003 - val_accuracy: 1.0000
# Epoch 86/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2805 - accuracy: 0.9667 - val_loss: 0.2944 - val_accuracy: 1.0000
# Epoch 87/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2759 - accuracy: 0.9667 - val_loss: 0.2891 - val_accuracy: 1.0000
# Epoch 88/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2716 - accuracy: 0.9667 - val_loss: 0.2838 - val_accuracy: 1.0000
# Epoch 89/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2673 - accuracy: 0.9667 - val_loss: 0.2784 - val_accuracy: 1.0000
# Epoch 90/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2629 - accuracy: 0.9667 - val_loss: 0.2723 - val_accuracy: 1.0000
# Epoch 91/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2597 - accuracy: 0.9667 - val_loss: 0.2669 - val_accuracy: 1.0000
# Epoch 92/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2557 - accuracy: 0.9667 - val_loss: 0.2622 - val_accuracy: 1.0000
# Epoch 93/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2510 - accuracy: 0.9667 - val_loss: 0.2575 - val_accuracy: 1.0000
# Epoch 94/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2485 - accuracy: 0.9667 - val_loss: 0.2536 - val_accuracy: 1.0000
# Epoch 95/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2445 - accuracy: 0.9667 - val_loss: 0.2478 - val_accuracy: 1.0000
# Epoch 96/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2409 - accuracy: 0.9667 - val_loss: 0.2430 - val_accuracy: 1.0000
# Epoch 97/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2367 - accuracy: 0.9667 - val_loss: 0.2387 - val_accuracy: 1.0000
# Epoch 98/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2330 - accuracy: 0.9667 - val_loss: 0.2349 - val_accuracy: 1.0000
# Epoch 99/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2301 - accuracy: 0.9667 - val_loss: 0.2310 - val_accuracy: 1.0000
# Epoch 100/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2269 - accuracy: 0.9667 - val_loss: 0.2278 - val_accuracy: 1.0000
# Epoch 101/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2244 - accuracy: 0.9667 - val_loss: 0.2235 - val_accuracy: 1.0000
# Epoch 102/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2210 - accuracy: 0.9667 - val_loss: 0.2183 - val_accuracy: 1.0000
# Epoch 103/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2176 - accuracy: 0.9667 - val_loss: 0.2143 - val_accuracy: 1.0000
# Epoch 104/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2164 - accuracy: 0.9667 - val_loss: 0.2108 - val_accuracy: 1.0000
# Epoch 105/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2124 - accuracy: 0.9667 - val_loss: 0.2069 - val_accuracy: 1.0000
# Epoch 106/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2100 - accuracy: 0.9667 - val_loss: 0.2042 - val_accuracy: 1.0000
# Epoch 107/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2071 - accuracy: 0.9667 - val_loss: 0.2015 - val_accuracy: 1.0000
# Epoch 108/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2051 - accuracy: 0.9667 - val_loss: 0.1975 - val_accuracy: 1.0000
# Epoch 109/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2021 - accuracy: 0.9667 - val_loss: 0.1932 - val_accuracy: 1.0000
# Epoch 110/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1997 - accuracy: 0.9667 - val_loss: 0.1904 - val_accuracy: 1.0000
# Epoch 111/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1978 - accuracy: 0.9667 - val_loss: 0.1871 - val_accuracy: 1.0000
# Epoch 112/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1945 - accuracy: 0.9667 - val_loss: 0.1837 - val_accuracy: 1.0000
# Epoch 113/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1920 - accuracy: 0.9667 - val_loss: 0.1814 - val_accuracy: 1.0000
# Epoch 114/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1905 - accuracy: 0.9667 - val_loss: 0.1796 - val_accuracy: 1.0000
# Epoch 115/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1895 - accuracy: 0.9667 - val_loss: 0.1767 - val_accuracy: 1.0000
# Epoch 116/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1865 - accuracy: 0.9667 - val_loss: 0.1722 - val_accuracy: 1.0000
# Epoch 117/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1831 - accuracy: 0.9667 - val_loss: 0.1696 - val_accuracy: 1.0000
# Epoch 118/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1818 - accuracy: 0.9667 - val_loss: 0.1671 - val_accuracy: 1.0000
# Epoch 119/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1799 - accuracy: 0.9667 - val_loss: 0.1646 - val_accuracy: 1.0000
# Epoch 120/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1784 - accuracy: 0.9667 - val_loss: 0.1617 - val_accuracy: 1.0000
# Epoch 121/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1765 - accuracy: 0.9667 - val_loss: 0.1592 - val_accuracy: 1.0000
# Epoch 122/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1743 - accuracy: 0.9667 - val_loss: 0.1567 - val_accuracy: 1.0000
# Epoch 123/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1724 - accuracy: 0.9667 - val_loss: 0.1543 - val_accuracy: 1.0000
# Epoch 124/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1705 - accuracy: 0.9667 - val_loss: 0.1521 - val_accuracy: 1.0000
# Epoch 125/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1693 - accuracy: 0.9667 - val_loss: 0.1500 - val_accuracy: 1.0000
# Epoch 126/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1680 - accuracy: 0.9667 - val_loss: 0.1476 - val_accuracy: 1.0000
# Epoch 127/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1667 - accuracy: 0.9667 - val_loss: 0.1456 - val_accuracy: 1.0000
# Epoch 128/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1656 - accuracy: 0.9667 - val_loss: 0.1436 - val_accuracy: 1.0000
# Epoch 129/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1626 - accuracy: 0.9667 - val_loss: 0.1414 - val_accuracy: 1.0000
# Epoch 130/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1612 - accuracy: 0.9667 - val_loss: 0.1396 - val_accuracy: 1.0000
# Epoch 131/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.
- accuracy: 0.9889 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 498/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0659 - accuracy: 0.9889 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 499/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0653 - accuracy: 0.9889 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 500/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0665 - accuracy: 0.9778 - val_loss: 0.0212 - val_accuracy: 1.0000
# 2/2 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Performances du modèle
#
# > Nous voulons maintenant effectuer un diagnostic de notre modèle. Pour cela, nous allons calculer une matrice de confusion sur l'échantillon de test.
# >
# > Néanmoins, si nous essayons de prédire la classe de l'échantillon de test, la méthode **`predict`** du modèle renvoie un **vecteur de probabilités** où chaque élément est la probabilité d'appartenance à la classe correspondant à son indice.
# >
# > Pour utiliser la fonction `classification_report` du sous-module **metrics** de **scikit-learn**, il faut que le vecteur de la prédiction et le vecteur de la classe réelle soient composés d'entiers.
# >
# > Nous allons alors utiliser la méthode `argmax` d'un *array* **numpy** pour savoir à quelle classe correspondent les vecteurs binaires et les vecteurs de probabilités.
#
# * **(a)** Prédire les classes de l'échantillon **X_test** à l'aide de la méthode `predict` du modèle. Stocker le résultat dans un tableau nommé **test_pred**.
#
#
# * **(b)** Appliquer la méthode `argmax` sur les tableaux **test_pred** pour obtenir des vecteurs d'entiers correspondant aux classes prédites et réelles. Il faudra passer l'argument 'axis = 1' pour que l'argmax soit calculée sur les colonnes et non les lignes. Stocker les sorties des appels de la méthode `argmax` dans un tableau nommés **test_pred_class** et les valeurs réelles dans **y_test_class**.

# %%
## Insérez votre code ici

# %%
test_pred = model.predict(X_test)


y_test_class = y_test
y_pred_class = np.argmax(test_pred,axis=1)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %% [markdown]
# * **(c)** Afficher un compte-rendu évaluatif détaillé de la perfomance du modèle grâce à la fonction `classification_report` du sous-module **metrics** de **scikit-learn**.

# %%
## Insérez votre code ici

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.94      1.00      0.97        15
#            2       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
#
# [[19  0  0]
#  [ 0 15  0]
#  [ 0  1 15]]

# %% [markdown]
# >Comparativement au modèle avec un seul perceptron, les résultats de classification semble nettemenent meilleurs avec plusieurs couches Denses.
#
# <hr style="border-width:2px;border-color:#75DFC1">
# <h2 style = "text-align:center" > Ce qu'il faut retenir </h2>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# > * L'algorithme du **perceptron multicouche** est particulièrement efficace pour les problèmes de **classification**.
# > * On utilise la fonction de loss **`sparse categorical crossentropy`** pour un problème de classification.
# > * On peut construire simplement un **MLP** sur **Keras** en utilisant une construction **séquentielle** quand l'architecture est simple. La construction **fonctionnelle** est plus polyvalente.
# > * On entraîne le réseau de neurones en le parcourant à l'aide des paramètres **`batch_size`** et **`epoch`**.
#
# >Vous pouvez retrouver toutes les fonctionnalités de **`keras`** dans **`tensorflow.keras`**. Il y a notamment les "couches de neurones" dans **`tensorflow.keras.layers`** :
# >
# > | Définition          | Classe               |
# > | :-----------------: |:--------------------:|
# > | Dense layer         | `Dense`              |
# > | Convolution 2D      | `Conv2D`             |
# > | Dropout             | `Dropout`            |
# > | Batch Normalization | `BatchNormalization` |
# > | Average Pooling 2D  | `AveragePooling2D`   |
# > | Flatten             | `Flatten`            |
# > | RNN                 | `RNN`                |
# > | LSTM                | `LSTM`               |
# > | GRU                 | `GRU`                |
